# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# !pip install nltk
import nltk
nltk.download('punkt')
clear_output()

if not os.path.exists("articles/"):
  # !wget https://zenodo.org/record/1239675/files/articles.zip?download=1 -O articles.zip
  # !unzip articles.zip
  # !rm articles.zip
  clear_output()
  print("Data successfully downloaded")
else:
  print("Data already downloaded")


random_seed = 176249
# Out:
# Data successfully downloaded

# %% [markdown]
# # Clasificación de Orientaciones políticas
#
# En este notebook vamos a tratar de predecir la orientación política del autor de una nota periodística a partir del texto de dicha nota.
#
#
# El primer paso para ello es leer los datos. En este caso, se tiene un *data frame* con artículos de diarios y la anotación de la orientación política (*left*, *right* o *mainstream*).

# %%
def read_data(test_size=0.2,random_state=0):
  data = {
      # "author": [],
      # "title": [],
      "mainText": [],
      "orientation": [],
      # "veracity": []
  }
  index = []
  for filename in os.listdir("articles/"):
    root = ET.parse(f"articles/{filename}").getroot()
    index.append(int(filename.split(".")[0]))
    for elem in root:
      if elem.tag in data.keys():
        data[elem.tag].append(elem.text)
  data = pd.DataFrame(data,index=index)
  data = data[data.notna().all(axis="columns")]
  data = data.sample(frac=1,random_state=random_state)
  N = len(data)
  train_split, test_split = data.iloc[int(N*test_size):,:], data.iloc[:int(N*test_size),:]
  train_split = train_split.reset_index(drop=True)
  test_split = test_split.reset_index(drop=True)
  return train_split, test_split
  
train_split, test_split = read_data(test_size=0.2,random_state=random_seed)
train_split
# Out:
#                                                mainText orientation
# 0     #5. Denmark pays students $900 a month to atte...        left
# 1     Politico POLITICO's must-read briefing on what...  mainstream
# 2     Dear President Bush. I am interested in buying...       right
# 3     Just days after the University of North Dakota...        left
# 4     Washington (CNN)The Senate Wednesday rejected ...  mainstream
# ...                                                 ...         ...
# 1279  The rioters in Charlotte may think they’re pro...       right
# 1280  Last October, Hillary Clinton and her top aide...  mainstream
# 1281  Kansas is bleeding money and jobs and Governor...        left
# 1282  To cap off a week in which police officers sho...        left
# 1283  It’s time for Episode 21 of the 2016 Nerdcast,...  mainstream
#
# [1284 rows x 2 columns]

# %%
train_split.loc[0, "mainText"]
# Out:
# '#5. Denmark pays students $900 a month to attend college. Thanks to Vermont Senator Bernie Sanders’ proud identification as a Democratic Socialist and allusion to Denmark as an ideal social democracy, Denmark is being discussed throughout the news media. But what few outlets are brave enough to report is that, by almost every measurable standard, Danish socialism runs circles around American capitalism. Here are a few examples:  Denmark has a tremendous social safety net for unemployed workers — any worker who worked at least 52 weeks over a three-year period can qualify to have 90 percent of their original salary paid for, for up to two years. The Danish government also has plentiful training programs for out-of-work Danes. As a result, 73 percent of Danes between 15 and 64 have a paying job, compared to 67 percent of Americans. World Bank data on healthcare costs in developed nations. According to the Organisation for Economic Co-Operation and Development (OECD), the US spends twice as much per capita on healthcare than in Denmark, where taxpayer-funded universal healthcare is available for all citizens. 2009 OECD data shows that the U.S. spent an average of $7,290 per person on healthcare. Denmark spent just $3,512. World Bank data, as seen in the chart above, shows Danish healthcare costs are about $3,000 less per capita than in the US.  The World Happiness Report, which determines which nation’s population is the “happiest” using criteria like life expectancy, GDP, social safety nets, as well as factors like “perception of corruption” and “freedom to make life choices,” found that Denmark was the happiest country. The US, in the meantime, ranked #17 on the same list.  Denmark leads every other OECD nation in work-life balance. Danes work an average of 37 hours a week, earn an average of $46,000 USD annually, and have the right to 5 weeks of paid vacation per year. Here in the US, the average worker puts in an average of 47 hours a week, and only takes 16 days of vacation a year. This is largely due to a more stressful work climate, in which wages are stagnating while costs are rising. Combine that with a highly-competitive job market, and that means more Americans are willing to chain themselves to their desk then to risk taking vacation days and coming back to find someone else took their job. An actual college campus in Denmark. Here in the US, the cost of going to college has soared by over 500 percent in the last 30 years. But in Denmark, not only is college free, but students are actually paid $900 USD per month to go to school, provided they live on their own. And this funding lasts up to six years. By contrast, the average US student pays over $31,000 a year in tuition to attend a private university, out-of-state residents at public universities pay $22,000 a year in tuition, and tuition costs for in-state residents at those same universities is still over $9,000. Per capita income data from the World Bank. In Denmark, despite a short work week and a generous social safety net, workers make more than enough to meet basic needs. According to per capita income data from the World Bank, Denmark’s per capita income is roughly $5,000 higher than in the US.  The benefits of living in Denmark are far-reaching — out of all OECD countries, Denmark has the second-lowest poverty rate at 0.6 percent. To compare, the OECD average of 11.3 percent is still lower than the 14.5 \xa0percent poverty rate in the US. So all this socialist nanny-state coddling must be making all the businesses flee Denmark as fast as they can, right? Wrong.  In 2014, Forbes ranked Denmark as the #1 best country for business. Forbes used 11 different criteria to rank countries — innovation, property rights, red tape, taxes, investor protection, stock market performance, technology, corruption, personal freedom, freedom of trade, and monetary freedom. Under the same criteria, the US ranked #18.  The Danish government gives new parents an average of 52 we ...

# %% [markdown]
# Una práctica muy común para procesar texto es normalizarlo. Algunas técnicas comunes son:
# * Eliminar caracteres raros e inusuales
# * Convertir todo a minúsculas
# * Eliminar palabras que no contienen información relevante (*stop words*)
# * *Lemmatization*
# * *Stemming*

# %%
def normalize_text(corpus,stop_words=None):

  # Convierto a lowercase
  corpus_lower = corpus.str.lower()

  # Elimino signos de puntuación, caracteres raros, etc.
  normalized_corpus = corpus_lower.str.replace(r"[^\w\d\s]+","",regex=True)

  # Elimino los stopwords
  if stop_words is not None:
    stop_words = "|".join(stop_words)
    normalized_corpus = normalized_corpus.str.replace(stop_words,"",regex=True)

  # Elimino espacios innecesarios
  normalized_corpus = normalized_corpus.str.replace(r"\s+"," ",regex=True)

  return normalized_corpus

train_data, test_data = read_data(test_size=0.2,random_state=random_seed)
train_data["mainText"] = normalize_text(train_data["mainText"],stop_words=None)
train_data
# Out:
#                                                mainText orientation
# 0     5 denmark pays students 900 a month to attend ...        left
# 1     politico politicos mustread briefing on whats ...  mainstream
# 2     dear president bush i am interested in buying ...       right
# 3     just days after the university of north dakota...        left
# 4     washington cnnthe senate wednesday rejected a ...  mainstream
# ...                                                 ...         ...
# 1279  the rioters in charlotte may think theyre prot...       right
# 1280  last october hillary clinton and her top aides...  mainstream
# 1281  kansas is bleeding money and jobs and governor...        left
# 1282  to cap off a week in which police officers sho...        left
# 1283  its time for episode 21 of the 2016 nerdcast p...  mainstream
#
# [1284 rows x 2 columns]

# %% [markdown]
# Una vez preprocesado, es necesario definir el vocabulario. Es decir, el conjunto de palabras que van a ser consideradas en la extracción de *features*.

# %%
from nltk import word_tokenize
from collections import defaultdict

def create_vocabulary(corpus,tokenizer,max_tokens=40000,min_freq=1):
  counts = defaultdict(lambda: 0)
  for comment in tqdm(corpus):
    for token in tokenizer(comment):
      counts[token] += 1

  valid_tokens = sorted([tk for tk in counts.keys() if counts[tk] >= min_freq],key=counts.get,reverse=True)[:max_tokens]
  counts = [counts[tk] for tk in valid_tokens]
  return pd.Series(counts,index=valid_tokens)

train_data, test_data = read_data()
train_data["mainText"] = normalize_text(train_data["mainText"],stop_words=["the","to","and","of","a","in","that","for","on","this","at","on"])
vocab = create_vocabulary(train_data["mainText"],word_tokenize,max_tokens=10000,min_freq=5)

fig, ax = plt.subplots(1,1,figsize=(20,8))
vocab[:100].plot(kind="bar",ax=ax,fontsize=10)
ax.grid(True)
# Out:
# 100%|██████████| 1284/1284 [00:02<00:00, 611.10it/s]

# %% [markdown]
# Una vez hecho esto, es posible vectorizar cada noticia haciendo lo que se conoce como una "bolsa de palabras" (*bag of words*). Es decir, cada documento (noticia) de la base de datos va a consistir en un vecor que contenga en sus componentes la cantidad de veces que aparecieron las palabras del vocabulario en él.

# %%
def vectorize(corpus,tokenizer,vocab):
  N = len(vocab)
  corpus_size = len(corpus)
  X = np.zeros((len(corpus),N))

  token2idx = {tk: i for i, tk in enumerate(vocab.index)}
  for i, article in enumerate(tqdm(corpus)):
    for w in tokenizer(article):
      if w in vocab.index:
        idx = token2idx[w]
        X[i,idx] += 1
  
  return X
        

train_data, test_data = read_data()
train_data["mainText"] = normalize_text(train_data["mainText"],stop_words=["the","to","and","of","a","in","that","for","on","this","at","on"])
test_data["mainText"] = normalize_text(test_data["mainText"],stop_words=["the","to","and","of","a","in","that","for","on","this","at","on"])

vocab = create_vocabulary(train_data["mainText"],word_tokenize,max_tokens=10000,min_freq=5)
X_train = vectorize(train_data["mainText"],word_tokenize,vocab)
y_train = train_data["orientation"].map({"mainstream": 0, "right": 1, "left": 2})

X_test = vectorize(test_data["mainText"],word_tokenize,vocab)
y_test = test_data["orientation"].map({"mainstream": 0, "right": 1, "left": 2})
# Out:
# 100%|██████████| 1284/1284 [00:02<00:00, 613.93it/s]
# 100%|██████████| 1284/1284 [00:02<00:00, 466.08it/s]
# 100%|██████████| 320/320 [00:00<00:00, 433.38it/s]

# %% [markdown]
# ## Baseline
#
# *Show time!* Ahora sí vamos a clasificar noticias. Cuando tenemos una base de datos nueva, una buena práctica es utilizar un modelo ingénuo (*dummy* o *naive*) para evaluarlo. En clasificación es muy común utilizar un modelo que aprende cuál fue la clase más frecuente durante el entrenamiento y elige siempre ésta cuando tiene que realizar una predicción. Esto puede implementarse fácilmente utilizando el objeto `DummyClassifier` de [scikit-learn](https://scikit-learn.org/stable/index.html).
#
# Para evaluar nuestro clasificación vamos a utilizar algunas funciones de la librería `metrics` del mismo paquete. En particular, `plot_confusion_matrix` nos muestra la matriz de confusión del problema de clasificación.

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

def show_results(y_true,y_pred):

  # Plot confusion matrix
  fig, ax = plt.subplots(1,1,figsize=(10,10))
  dsp = ConfusionMatrixDisplay.from_predictions(y_true,y_pred,display_labels=["mainstream", "right", "left"],ax=ax)

  # Show Classification report
  print(classification_report(y_true,y_pred))


clf = DummyClassifier(strategy="most_frequent")
clf.fit(X_train,y_train)
y_test_pred = clf.predict(X_test)
print("Baseline model:")
show_results(y_test,y_test_pred)
# Out:
# Baseline model:
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68       166
#            1       0.00      0.00      0.00       109
#            2       0.00      0.00      0.00        45
#
#     accuracy                           0.52       320
#    macro avg       0.17      0.33      0.23       320
# weighted avg       0.27      0.52      0.35       320
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## BOW + Clasificador Softmax
#
# **Tarea 1: Implementar una vectorización por bolsa de palabras y entrenar un clasificador Softmax para clasificar orientaciones políticas. Utilizar exactitud como métrica de evaluación.**
#
# Analizar:
# * ¿Funciona mejor el clasificador entrenado que el modelo baseline?
# * ¿Cómo influye la cantidad de palabras elegidas? ¿Y la frecuencia mínima de aparición?
# * ¿Qué importancia tienen las stop words en este caso?
# * ¿Hay overfitting? ¿Cómo podría reducirlo?

# %%
def get_and_bow_vectorize_data(
    stop_words=None,
    max_tokens=10000,
    min_freq=1
):

  train_data, test_data = read_data()
  train_data["mainText"] = normalize_text(train_data["mainText"],stop_words=stop_words)
  test_data["mainText"] = normalize_text(test_data["mainText"],stop_words=stop_words)

  vocab = create_vocabulary(train_data["mainText"],word_tokenize,max_tokens=max_tokens,min_freq=min_freq)
  X_train = vectorize(train_data["mainText"],word_tokenize,vocab)
  y_train = train_data["orientation"].map({"mainstream": 0, "right": 1, "left": 2})

  X_test = vectorize(test_data["mainText"],word_tokenize,vocab)
  y_test = test_data["orientation"].map({"mainstream": 0, "right": 1, "left": 2})

  return X_train, y_train, X_test, y_test

# Leo y vectorizo las noticias
X_train, y_train, X_test, y_test = get_and_bow_vectorize_data()

# %%
print(X_train.shape)

def normalizar(x):
  mean = x.mean(axis = 0)
  desvio = x.std(axis = 0)
  return (x - mean)/desvio

X_normalizado = normalizar(X_train)
# Out:
# (1284, 8953)

# %%
import tensorflow as tf
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(3, input_dim=8953))
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 3)                 26862
#
# =================================================================
# Total params: 26,862
# Trainable params: 26,862
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=1)
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["accuracy"])
hist = model.fit(x=X_normalizado, y=y_train, batch_size = len(X_train), epochs=1000,callbacks=[es])
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 370ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 10/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 11/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 12/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 13/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 14/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 15/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 16/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 17/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 18/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 19/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 20/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 21/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 22/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 23/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 24/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 25/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 26/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 27/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 28/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 29/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 30/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 31/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 32/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 33/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 34/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 35/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 36/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 37/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 38/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 39/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 40/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 41/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 42/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 43/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 44/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 45/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 46/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 47/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 48/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 49/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 50/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 51/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 52/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 53/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 54/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 55/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 56/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 57/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 58/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 59/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 60/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 61/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 62/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 63/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 64/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 65/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 66/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 67/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 68/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 69/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 70/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 71/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 72/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 73/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 74/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 75/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 76/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 77/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 78/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 79/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 80/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 81/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 82/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 83/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 84/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 85/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 86/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 87/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 88/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 89/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 90/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 91/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 92/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 93/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 94/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 95/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 96/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 97/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 98/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 99/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 100/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 101/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 102/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 103/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 104/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 105/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 106/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 107/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 108/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 109/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 110/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 111/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 112/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 113/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 114/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 115/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 116/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 117/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 118/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 119/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 120/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 121/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 122/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 123/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 124/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 125/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 126/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 127/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 128/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 129/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 130/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 131/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 132/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 133/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 134/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 135/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 136/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 137/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 138/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 139/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 140/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 141/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 142/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 143/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 144/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 145/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 146/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 147/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 148/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 149/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 150/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 151/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 152/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 153/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 154/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 155/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 156/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 157/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 158/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 159/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 160/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 161/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 162/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 163/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 164/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 165/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 166/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 167/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 168/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 169/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 170/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 171/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 172/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 173/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 174/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 175/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 176/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 177/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 178/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 179/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 180/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 181/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 182/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 183/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 184/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 185/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 186/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 187/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 188/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 189/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 190/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 191/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 192/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 193/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 194/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 195/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 196/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 197/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 198/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 199/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 200/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 201/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 202/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 203/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 204/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 205/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 206/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 207/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 208/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 209/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 210/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 211/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 212/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 213/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 214/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 215/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 216/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 217/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 218/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 219/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 220/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 221/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 222/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 223/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 224/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 225/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 226/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 227/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 228/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 229/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 230/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 231/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 232/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 233/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 234/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 235/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 236/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 237/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 238/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 239/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 240/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 241/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 242/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 243/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 244/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 245/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 246/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 247/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 248/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 249/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 250/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 251/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 252/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 253/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 254/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 255/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 256/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 257/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 258/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 259/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 260/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 261/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 262/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 263/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 264/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 265/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 266/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 267/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 268/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 269/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 270/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 271/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 272/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 273/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 274/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 275/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 276/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 277/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 278/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 279/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 280/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 281/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 282/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 283/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 284/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 285/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 286/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 287/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 288/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 289/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 290/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 291/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 292/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 293/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 294/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 295/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 296/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 297/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 298/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 299/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 300/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 301/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 302/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 303/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 304/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 305/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 306/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 307/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 308/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 309/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 310/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 311/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 312/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 313/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 314/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 315/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 316/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 317/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 318/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 319/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 320/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 321/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 322/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 323/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 324/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 325/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 326/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 327/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 328/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 329/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 330/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 331/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 332/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 333/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 334/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 335/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 336/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 337/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 338/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 339/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 340/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 341/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 342/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 343/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 344/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 345/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 346/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 347/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 348/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 349/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 350/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 351/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 352/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 353/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 354/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 355/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 356/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 357/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 358/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 359/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 360/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 361/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 362/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 363/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 364/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 365/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 366/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 367/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 368/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 369/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 370/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 371/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 372/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 373/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 374/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 375/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 376/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 377/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 378/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 379/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 380/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 381/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 382/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 383/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 384/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 385/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 386/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 387/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 388/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 389/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 390/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 391/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 392/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 393/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 394/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 395/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 396/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 397/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 398/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 399/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 400/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 401/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 402/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 403/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 404/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 405/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 406/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 407/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 408/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 409/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 410/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 411/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 412/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 413/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 414/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 415/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 416/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 417/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 418/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 419/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 420/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 421/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 422/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 423/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 424/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 425/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 426/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 427/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 428/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 429/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 430/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 431/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 432/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 433/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 434/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 435/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 436/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 437/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 438/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 439/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 440/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 441/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 442/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 443/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 444/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 445/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 446/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 447/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 448/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 449/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 450/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 451/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 452/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 453/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 454/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 455/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 456/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 457/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 458/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 459/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 460/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 461/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 462/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 463/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 464/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 465/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 466/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 467/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 468/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 469/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 470/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 471/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 472/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 473/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 474/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 475/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 476/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 477/1000
# ...
# Epoch 849/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 850/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.9953e-04 - accuracy: 1.0000
# Epoch 851/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 9.9873e-04 - accuracy: 1.0000
# Epoch 852/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.9793e-04 - accuracy: 1.0000
# Epoch 853/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.9713e-04 - accuracy: 1.0000
# Epoch 854/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 9.9633e-04 - accuracy: 1.0000
# Epoch 855/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.9553e-04 - accuracy: 1.0000
# Epoch 856/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.9473e-04 - accuracy: 1.0000
# Epoch 857/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.9394e-04 - accuracy: 1.0000
# Epoch 858/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 9.9315e-04 - accuracy: 1.0000
# Epoch 859/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 9.9235e-04 - accuracy: 1.0000
# Epoch 860/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.9156e-04 - accuracy: 1.0000
# Epoch 861/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.9077e-04 - accuracy: 1.0000
# Epoch 862/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.8998e-04 - accuracy: 1.0000
# Epoch 863/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.8919e-04 - accuracy: 1.0000
# Epoch 864/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.8841e-04 - accuracy: 1.0000
# Epoch 865/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.8762e-04 - accuracy: 1.0000
# Epoch 866/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.8684e-04 - accuracy: 1.0000
# Epoch 867/1000
# 1/1 [==============================] - 0s 137ms/step - loss: 9.8606e-04 - accuracy: 1.0000
# Epoch 868/1000
# 1/1 [==============================] - 0s 191ms/step - loss: 9.8528e-04 - accuracy: 1.0000
# Epoch 869/1000
# 1/1 [==============================] - 0s 212ms/step - loss: 9.8450e-04 - accuracy: 1.0000
# Epoch 870/1000
# 1/1 [==============================] - 0s 200ms/step - loss: 9.8372e-04 - accuracy: 1.0000
# Epoch 871/1000
# 1/1 [==============================] - 0s 230ms/step - loss: 9.8294e-04 - accuracy: 1.0000
# Epoch 872/1000
# 1/1 [==============================] - 0s 178ms/step - loss: 9.8216e-04 - accuracy: 1.0000
# Epoch 873/1000
# 1/1 [==============================] - 0s 186ms/step - loss: 9.8139e-04 - accuracy: 1.0000
# Epoch 874/1000
# 1/1 [==============================] - 0s 138ms/step - loss: 9.8062e-04 - accuracy: 1.0000
# Epoch 875/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.7984e-04 - accuracy: 1.0000
# Epoch 876/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 9.7907e-04 - accuracy: 1.0000
# Epoch 877/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.7830e-04 - accuracy: 1.0000
# Epoch 878/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 9.7753e-04 - accuracy: 1.0000
# Epoch 879/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 9.7677e-04 - accuracy: 1.0000
# Epoch 880/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.7600e-04 - accuracy: 1.0000
# Epoch 881/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.7524e-04 - accuracy: 1.0000
# Epoch 882/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.7448e-04 - accuracy: 1.0000
# Epoch 883/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 9.7371e-04 - accuracy: 1.0000
# Epoch 884/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.7295e-04 - accuracy: 1.0000
# Epoch 885/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 9.7219e-04 - accuracy: 1.0000
# Epoch 886/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.7143e-04 - accuracy: 1.0000
# Epoch 887/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.7068e-04 - accuracy: 1.0000
# Epoch 888/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 9.6992e-04 - accuracy: 1.0000
# Epoch 889/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.6917e-04 - accuracy: 1.0000
# Epoch 890/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 9.6841e-04 - accuracy: 1.0000
# Epoch 891/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.6766e-04 - accuracy: 1.0000
# Epoch 892/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.6691e-04 - accuracy: 1.0000
# Epoch 893/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.6616e-04 - accuracy: 1.0000
# Epoch 894/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.6541e-04 - accuracy: 1.0000
# Epoch 895/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.6466e-04 - accuracy: 1.0000
# Epoch 896/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.6391e-04 - accuracy: 1.0000
# Epoch 897/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 9.6317e-04 - accuracy: 1.0000
# Epoch 898/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 9.6243e-04 - accuracy: 1.0000
# Epoch 899/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.6168e-04 - accuracy: 1.0000
# Epoch 900/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.6094e-04 - accuracy: 1.0000
# Epoch 901/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.6020e-04 - accuracy: 1.0000
# Epoch 902/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.5946e-04 - accuracy: 1.0000
# Epoch 903/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.5872e-04 - accuracy: 1.0000
# Epoch 904/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 9.5799e-04 - accuracy: 1.0000
# Epoch 905/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.5725e-04 - accuracy: 1.0000
# Epoch 906/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 9.5652e-04 - accuracy: 1.0000
# Epoch 907/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.5578e-04 - accuracy: 1.0000
# Epoch 908/1000
# 1/1 [==============================] - 0s 97ms/step - loss: 9.5505e-04 - accuracy: 1.0000
# Epoch 909/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.5432e-04 - accuracy: 1.0000
# Epoch 910/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 9.5359e-04 - accuracy: 1.0000
# Epoch 911/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.5286e-04 - accuracy: 1.0000
# Epoch 912/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 9.5213e-04 - accuracy: 1.0000
# Epoch 913/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 9.5140e-04 - accuracy: 1.0000
# Epoch 914/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 9.5068e-04 - accuracy: 1.0000
# Epoch 915/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 9.4996e-04 - accuracy: 1.0000
# Epoch 916/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.4923e-04 - accuracy: 1.0000
# Epoch 917/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.4851e-04 - accuracy: 1.0000
# Epoch 918/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.4779e-04 - accuracy: 1.0000
# Epoch 919/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 9.4707e-04 - accuracy: 1.0000
# Epoch 920/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.4635e-04 - accuracy: 1.0000
# Epoch 921/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.4563e-04 - accuracy: 1.0000
# Epoch 922/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.4492e-04 - accuracy: 1.0000
# Epoch 923/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.4420e-04 - accuracy: 1.0000
# Epoch 924/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.4349e-04 - accuracy: 1.0000
# Epoch 925/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.4277e-04 - accuracy: 1.0000
# Epoch 926/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 9.4206e-04 - accuracy: 1.0000
# Epoch 927/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.4135e-04 - accuracy: 1.0000
# Epoch 928/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 9.4064e-04 - accuracy: 1.0000
# Epoch 929/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 9.3993e-04 - accuracy: 1.0000
# Epoch 930/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 9.3922e-04 - accuracy: 1.0000
# Epoch 931/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.3852e-04 - accuracy: 1.0000
# Epoch 932/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.3781e-04 - accuracy: 1.0000
# Epoch 933/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.3711e-04 - accuracy: 1.0000
# Epoch 934/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.3641e-04 - accuracy: 1.0000
# Epoch 935/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.3570e-04 - accuracy: 1.0000
# Epoch 936/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.3500e-04 - accuracy: 1.0000
# Epoch 937/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.3430e-04 - accuracy: 1.0000
# Epoch 938/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.3361e-04 - accuracy: 1.0000
# Epoch 939/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 9.3291e-04 - accuracy: 1.0000
# Epoch 940/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.3221e-04 - accuracy: 1.0000
# Epoch 941/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 9.3152e-04 - accuracy: 1.0000
# Epoch 942/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.3082e-04 - accuracy: 1.0000
# Epoch 943/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.3012e-04 - accuracy: 1.0000
# Epoch 944/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.2943e-04 - accuracy: 1.0000
# Epoch 945/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.2874e-04 - accuracy: 1.0000
# Epoch 946/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.2805e-04 - accuracy: 1.0000
# Epoch 947/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.2736e-04 - accuracy: 1.0000
# Epoch 948/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.2667e-04 - accuracy: 1.0000
# Epoch 949/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 9.2599e-04 - accuracy: 1.0000
# Epoch 950/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.2530e-04 - accuracy: 1.0000
# Epoch 951/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.2461e-04 - accuracy: 1.0000
# Epoch 952/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 9.2393e-04 - accuracy: 1.0000
# Epoch 953/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 9.2325e-04 - accuracy: 1.0000
# Epoch 954/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.2257e-04 - accuracy: 1.0000
# Epoch 955/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.2189e-04 - accuracy: 1.0000
# Epoch 956/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 9.2121e-04 - accuracy: 1.0000
# Epoch 957/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 9.2053e-04 - accuracy: 1.0000
# Epoch 958/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 9.1985e-04 - accuracy: 1.0000
# Epoch 959/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.1918e-04 - accuracy: 1.0000
# Epoch 960/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.1850e-04 - accuracy: 1.0000
# Epoch 961/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.1782e-04 - accuracy: 1.0000
# Epoch 962/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 9.1715e-04 - accuracy: 1.0000
# Epoch 963/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 9.1648e-04 - accuracy: 1.0000
# Epoch 964/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.1581e-04 - accuracy: 1.0000
# Epoch 965/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 9.1514e-04 - accuracy: 1.0000
# Epoch 966/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.1447e-04 - accuracy: 1.0000
# Epoch 967/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 9.1380e-04 - accuracy: 1.0000
# Epoch 968/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.1313e-04 - accuracy: 1.0000
# Epoch 969/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 9.1246e-04 - accuracy: 1.0000
# Epoch 970/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 9.1180e-04 - accuracy: 1.0000
# Epoch 971/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 9.1113e-04 - accuracy: 1.0000
# Epoch 972/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.1047e-04 - accuracy: 1.0000
# Epoch 973/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.0981e-04 - accuracy: 1.0000
# Epoch 974/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 9.0914e-04 - accuracy: 1.0000
# Epoch 975/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 9.0848e-04 - accuracy: 1.0000
# Epoch 976/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.0782e-04 - accuracy: 1.0000
# Epoch 977/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 9.0716e-04 - accuracy: 1.0000
# Epoch 978/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 9.0651e-04 - accuracy: 1.0000
# Epoch 979/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.0585e-04 - accuracy: 1.0000
# Epoch 980/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 9.0519e-04 - accuracy: 1.0000
# Epoch 981/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.0454e-04 - accuracy: 1.0000
# Epoch 982/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 9.0389e-04 - accuracy: 1.0000
# Epoch 983/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 9.0323e-04 - accuracy: 1.0000
# Epoch 984/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 9.0258e-04 - accuracy: 1.0000
# Epoch 985/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 9.0193e-04 - accuracy: 1.0000
# Epoch 986/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 9.0128e-04 - accuracy: 1.0000
# Epoch 987/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 9.0063e-04 - accuracy: 1.0000
# Epoch 988/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 8.9998e-04 - accuracy: 1.0000
# Epoch 989/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 8.9934e-04 - accuracy: 1.0000
# Epoch 990/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 8.9869e-04 - accuracy: 1.0000
# Epoch 991/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 8.9804e-04 - accuracy: 1.0000
# Epoch 992/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 8.9740e-04 - accuracy: 1.0000
# Epoch 993/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 8.9676e-04 - accuracy: 1.0000
# Epoch 994/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 8.9611e-04 - accuracy: 1.0000
# Epoch 995/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 8.9547e-04 - accuracy: 1.0000
# Epoch 996/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 8.9483e-04 - accuracy: 1.0000
# Epoch 997/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 8.9420e-04 - accuracy: 1.0000
# Epoch 998/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 8.9355e-04 - accuracy: 1.0000
# Epoch 999/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 8.9292e-04 - accuracy: 1.0000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 8.9228e-04 - accuracy: 1.0000

# %% [markdown]
# Una vez que entrene el modelo, obtengo las predicciones y calculo el argmax por fila (me quedo con el valor mas grande de cada fila de z)

# %%
z = model.predict(X_train)
#print(z)
y_hat = np.argmax(z, axis=1)
#print(y_hat.shape)
print(y_hat)
# Out:
# [0 0 2 ... 0 0 1]

# %% [markdown]
# Chequeo cuales valores fueron correctos

# %%
print("X test shape: ", X_test.shape)
print("y test shape: ", y_test.shape)
z_test = model.predict(X_test)
z_test.shape
# Out:
# X test shape:  (320, 8953)
# y test shape:  (320,)
# (320, 3)

# %% [markdown]
# ## Features selection
#
# **Tarea 2: Implementar una vectorización por palabras claves. Es decir, definir un vocabulario inspeccionando las noticias de la base de datos y tratar de hipotetizar qué palabras pueden servir para discriminar entre noticias de izquierda, derecha y *mainstream*. Una  vez hecho esto, implementar nuevamente el clasificador anterior y utilizarlo para predecir en este nuevo escenario.**
#
# Hint: para este análisis puede que sea necesario hacer una inspección de los datos y ver qué palabras aparecieron en cada categoría. En este punto, cualquier idea *out-of-the-box* también puede ser útil :)

# %%
def get_data_and_select_keywords(
    stop_words=None,
):

  train_data, test_data = read_data()
  train_data["mainText"] = normalize_text(train_data["mainText"],stop_words=stop_words)
  test_data["mainText"] = normalize_text(test_data["mainText"],stop_words=stop_words)

  # TODO: implementar selección de palabras claves.
  vocab = {}
  # END TODO

  X_train = vectorize(train_data["mainText"],word_tokenize,vocab)
  y_train = train_data["orientation"].map({"mainstream": 0, "right": 1, "left": 2})

  X_test = vectorize(test_data["mainText"],word_tokenize,vocab)
  y_test = test_data["orientation"].map({"mainstream": 0, "right": 1, "left": 2})

  return X_train, y_train, X_test, y_test

# Leo y vectorizo las noticias
X_train, y_train, X_test, y_test = get_data_and_select_keywords()

# TODO: Implementar Softmax Classifier
# ...
# END TODO
